# %% [markdown]
# **1. Introduction**
#
# **Company Introduction**
#
# My client for this project is an NGO.
# The Happiness Foundation has been around for the last two decades and spans across more than 150 countries.
# The NGO comprises professionals and grassroots workers from various walks of life.
# The team includes young passionate individuals from different backgrounds who derive contentment by helping the needy, poor, and down-trodden.
#
# **Current Scenario**
#
# The foundation has gathered teams from across the world who have been invited for an exhibition of a system that determines the happiness of a particular individual based on certain factors.

# %% [markdown]
# **2. Problem Statement**
#
# **The current process suffers from the following problems**:
#
# With the help of Gallup World Polls, they determine the happiness of individuals across various countries.
# The current process is a resource and time-consuming given that data has to be collected from individuals, processed, analyzed, and then determined what the future results of polls will look like.
# They want to automate the process of predicting the future poll results based on certain given factors.
#
# They have hired you as a data science consultant. They want to supplement their analysis and prediction with a more feasible approach.
#
# **My Role**
#
# I am given datasets of the world happiness report with Life Ladder indicating the happiness score of the individual.
# My task is to build a regression model using the datasets.
# Because there was no machine learning model for this problem in the foundation, you don’t have a quantifiable win condition. You need to build the best possible model.
#
# **Project Deliverables**
#
# Deliverable: Predicts the Life Ladder score of individuals.
# Machine Learning Task: Regression
# Target Variable: Life Ladder
# Win Condition: N/A (best possible model)
#
# **Evaluation Metric**
# The model evaluation will be based on the R2 score.

# %% [markdown]
# **3. Data Description**
#
# The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity.
# Also included in the dataset is the column Life Ladder which has the individual’s happiness score.
# This is the data that we have to predict for **Life Ladder**.
#
# | Id | Column Name| Description|
# | :-- | :--| :--|
# |01| **Country name** | Represents the country name of the individual |
# |02| **Year** | Represents the year when the poll was conducted |
# |03|**Log GDP per capita**|Log of GDP per capita of the country|
# |04|**Social Support**|Represents the subjective social support received|
# |05|**Healthy life expectancy at birth**|Represents the healthy life expectancy at birth in the country|
# |06|**Generosity**|Represents the generosity factor based on many polled factors|
# |07|**Perceptions of corruption**|Represents an individual’s view on corruption in the country|
# |08|**Positive affect**|Represents the average score of happiness, laugh, and enjoyment scores of the concerned individual|
# |09|**Negative affect**|Represents the average score of sadness, worry, and anger scores of the concerned individual|
# |10|**ID**|Identifier of the individual|
# |11|**Freedom to make life choices**|Represents the freedom of choice score for the country|
# |12|**Life Ladder**|Represents the happiness score or subjective well-being|

# %% [markdown]
# **4.Importing Libraries**

# %%
# Run the below libraries
# !pip install -q datascience                                        
# !pip install -q pandas-profiling                                    
# !pip install -q yellowbrick

# %% [markdown]
# After upgrading the above libraries, you need to restart the runtime to make the libraries in sync.
#
# Make sure not to execute the cell above (3) and below (1) again after restarting the runtime.

# %%
# !pip install -q --upgrade pandas-profiling
# !pip install -q --upgrade yellowbrick

# %%
import pandas as pd                                                               # Importing for panel data analysis
from pandas_profiling import ProfileReport                                        # Import Pandas Profiling (To generate Univariate Analysis) 
pd.set_option('display.max_columns', None)                                        # Unfolding hidden features if the cardinality is high      
pd.set_option('display.max_colwidth', None)                                       # Unfolding the max feature width for better clearity      
pd.set_option('display.max_rows', None)                                           # Unfolding hidden data points if the cardinality is high
pd.set_option('display.float_format', lambda x: '%.5f' % x)                       # To suppress scientific notation over exponential values
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                                                                # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                                   # Importing pyplot interface using matplotlib                                              
import seaborn as sns                                                             # Importing seaborm library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
from sklearn.model_selection import train_test_split                              # To split the data in training and testing part 
from sklearn.preprocessing import StandardScaler                                  # Importing Standard Scaler library from preprocessing.                             
from sklearn.linear_model import LinearRegression                                 # Importing Linear Regression model
from sklearn.metrics import mean_squared_error                                    # To calculate the MSE of a regression model
from sklearn.metrics import mean_absolute_error                                   # To calculate the MAE of a regression model
from sklearn.metrics import r2_score                                              # To calculate the R-squared score of a regression model
from sklearn.metrics import accuracy_score                          # For calculating the accuracy for the model
from sklearn.metrics import precision_score                         # For calculating the Precision of the model
from sklearn.metrics import recall_score                            # For calculating the recall of the model
from sklearn.metrics import precision_recall_curve                  # For precision and recall metric estimation
from sklearn.metrics import confusion_matrix                        # For verifying model performance using confusion matrix
from sklearn.metrics import f1_score                                # For Checking the F1-Score of our model  
from sklearn.metrics import roc_curve                               # For Roc-Auc metric estimation
#-------------------------------------------------------------------------------------------------------------------------------
from sklearn.model_selection import train_test_split                # To split the data in training and testing part     
from sklearn.linear_model import LogisticRegression                 # To create the Logistic Regression Model
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics as metrics
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
from random import randint                                          # Importing to generate random integers
from sklearn.preprocessing import StandardScaler                    # Importing standard scaler to perform standardization
from sklearn.feature_selection import SelectFromModel               # To select features from model using Yellow bricks
 
from sklearn.naive_bayes import GaussianNB                          # To create a naive bayes model using algorithm
from sklearn.ensemble import RandomForestClassifier                 # To create a random forest model using algorithm
from sklearn.metrics import plot_confusion_matrix                   # To plot confusion matrix 
from yellowbrick.model_selection import FeatureImportances
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor, StackingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle                                   # To shuffle the data
from sklearn.impute import KNNImputer                               # To performing iterative imputing over missing data
from sklearn.preprocessing import StandardScaler                    # Importing standard scaler to perform standardization
from sklearn.base import BaseEstimator                              # To create custom transformers
from sklearn.base import ClassifierMixin                            # To create custom transformers
from sklearn.base import TransformerMixin                           # To create custom transformers
from sklearn.feature_selection import SelectFromModel               # To select features from model using Yellow bricks
from yellowbrick.model_selection import FeatureImportances          # To select important features out of the model
from sklearn.model_selection import KFold                           # To perform K-fold executions
from sklearn.naive_bayes import GaussianNB                          # To create a naive bayes model using algorithm
from sklearn.ensemble import RandomForestClassifier                 # To create a random forest model using algorithm
from sklearn.metrics import plot_confusion_matrix                   # To plot confusion matrix 
from yellowbrick.model_selection import FeatureImportances
from sklearn.model_selection import cross_validate                  # To calculate cross validation scores
from sklearn.model_selection import GridSearchCV                    # To tune the models
import time                                                         # Importing to calculate time
from sklearn import base

#-----------------------------------------------------------------------------------------

# %%
# Import Train Data
happy_train = pd.read_csv(r'C:\Users\vc00482003\Desktop\INSAIDclassdocs\ML\ML_Term6_Project\Project_10_Regression_World_Happiness_Report_1\train_data.csv')
print('Data Shape:', happy_train.shape)
happy_train.head()
# Out:
# Data Shape: (1559, 12)
#   Country name  year  Log GDP per capita  Social support  \
# 0       Jordan  2008             9.34300         0.76600
# 1      Estonia  2013            10.29900         0.90100
# 2       Sweden  2018            10.88100         0.93100
# 3   Tajikistan  2006             7.55400         0.72400
# 4       Kuwait  2014            10.94500             NaN
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                          64.22000                           NaN    -0.12700
# 1                          67.48000                       0.75400    -0.20100
# 2                          72.60000                       0.94200     0.07700
# 3                          60.64000                       0.70200    -0.08800
# 4                          65.80000                           NaN         NaN
#
#    Perceptions of corruption  Positive affect  Negative affect    ID  \
# ...

# %% [markdown]
# **4. Data Description**

# %%
# Describe Train data
happy_train.describe()
# Out:
#             year  Log GDP per capita  Social support  \
# count 1559.00000          1533.00000      1549.00000
# mean  2013.13149             9.36300         0.81269
# std      4.20603             1.16024         0.11876
# min   2005.00000             6.63500         0.29000
# 25%   2010.00000             8.46000         0.75300
# 50%   2013.00000             9.45600         0.83500
# 75%   2017.00000            10.33200         0.90500
# max   2020.00000            11.64800         0.98700
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                        1522.00000                    1537.00000
# mean                           63.33168                       0.74188
# std                             7.47831                       0.14233
# min                            32.30000                       0.26000
# 25%                            58.34000                       0.64600
# ...

# %% [markdown]
# 1. Average GDP per person is about **9.3**
# 2. Standard deviation of  Average GDP is not high from the max GDP of **11.6**
# 3. All features not not deviating a lot from the their mean
# 4. 25% people's GDP is less than or equal to **8.4**
# 5. 50% people's GDP is less than or equal to **9.45**
# 6. 75% people's GDP is less than or equal to **10.3**

# %%
# Check Skewness Train data
happy_train.skew()
# Out:
# C:\Users\vc00482003\AppData\Local\Temp\ipykernel_1628\3109224357.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   happy_train.skew()
# year                               -0.10746
# Log GDP per capita                 -0.29240
# Social support                     -1.13780
# Healthy life expectancy at birth   -0.72259
# Freedom to make life choices       -0.60636
# Generosity                          0.82825
# Perceptions of corruption          -1.53646
# Positive affect                    -0.34771
# Negative affect                     0.69647
# ID                                 -0.00205
# Life Ladder                         0.07500
# dtype: float64

# %% [markdown]
# 1. Social Support & Perception of corruption are slightly negatively skewed
# 2. Rest of the features are appear pretty homogenous

# %% [markdown]
# **5. Data Information**

# %%
# Check Train Data info
happy_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1559 entries, 0 to 1558
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1559 non-null   object
#  1   year                              1559 non-null   int64
#  2   Log GDP per capita                1533 non-null   float64
#  3   Social support                    1549 non-null   float64
#  4   Healthy life expectancy at birth  1522 non-null   float64
#  5   Freedom to make life choices      1537 non-null   float64
#  6   Generosity                        1488 non-null   float64
#  7   Perceptions of corruption         1473 non-null   float64
#  8   Positive affect                   1542 non-null   float64
#  9   Negative affect                   1545 non-null   float64
#  10  ID                                1559 non-null   int64
# ...

# %% [markdown]
# **Missing values found in below columns**
#
# 1. Log GDP per capita
# 2. Social support
# 3. Healthy life expectancy at birth
# 4. Freedom to make life choices
# 5. Generosity
# 6. Perceptions of corruption
# 7. Positive affect
# 8. Negative affect

# %%
# Finding NULL values in Trian data

#Creating a New dataframe
missing_frame = pd.DataFrame(index = happy_train.columns.values) 

#Adding a column in the newly created dataframe
missing_frame['Null Frequency'] = happy_train.isnull().sum().values

#Calculating the percentage of null values
nullpercent = happy_train.isnull().sum().values/happy_train.shape[0]

#Rounding the percentage of missing values and adding it to the dataFrame
missing_frame['Missing Null %age'] = np.round(nullpercent, decimals = 4) * 100

#Counting the number of 0 value present and adding it to the column in our dataFrame
missing_frame['Zero Frequency'] = happy_train[happy_train == 0].count().values

#Calculating the Percentage of Zero
zero_percent = happy_train[happy_train == 0].count().values / happy_train.shape[0]

#Rounding and adding a column the dataframe which consists of the percent of 0 value present.
missing_frame['Missing %age'] = np.round(zero_percent, decimals = 4) * 100
missing_frame.transpose()
# Out:
#                    Country name    year  Log GDP per capita  Social support  \
# Null Frequency          0.00000 0.00000            26.00000        10.00000
# Missing Null %age       0.00000 0.00000             1.67000         0.64000
# Zero Frequency          0.00000 0.00000             0.00000         0.00000
# Missing %age            0.00000 0.00000             0.00000         0.00000
#
#                    Healthy life expectancy at birth  \
# Null Frequency                             37.00000
# Missing Null %age                           2.37000
# Zero Frequency                              0.00000
# Missing %age                                0.00000
#
#                    Freedom to make life choices  Generosity  \
# Null Frequency                         22.00000    71.00000
# Missing Null %age                       1.41000     4.55000
# Zero Frequency                          0.00000     3.00000
# Missing %age                            0.00000     0.19000
#
# ...

# %% [markdown]
# **6. Data Profiling**

# %%
# Run profile report
profile = ProfileReport(df=happy_train)
profile.to_file(output_file='Pre Profiling Report.html')
print('Accomplished!')

# No Duplicate values are found in the data
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Accomplished!

# %% [markdown]
# **7. Data Prep-Processing**

# %%
# Imputing Missing values

# Imputing missing data for numerical data
# Have some patience, it may take some time :)
# CPU times: user 7min 27s, sys: 16.6 s, total: 7min 43s
# Wall time: 6min 57s
knn_imputer = KNNImputer()
raw_num = knn_imputer.fit_transform(happy_train[['Log GDP per capita', 'Social support',
       'Healthy life expectancy at birth', 'Freedom to make life choices',
       'Generosity', 'Perceptions of corruption', 'Positive affect',
       'Negative affect']])

# A new dataframe representing non-null values
raw_frame = pd.DataFrame(data=raw_num, columns=['Log GDP per capita', 'Social support',
       'Healthy life expectancy at birth', 'Freedom to make life choices',
       'Generosity', 'Perceptions of corruption', 'Positive affect',
       'Negative affect'])
# Updating original dataset with updated values
happy_train['Log GDP per capita'] = raw_frame['Log GDP per capita']
happy_train['Social support'] = raw_frame['Social support']
happy_train['Healthy life expectancy at birth'] = raw_frame['Healthy life expectancy at birth']
happy_train['Freedom to make life choices'] = raw_frame['Freedom to make life choices']
happy_train['Generosity'] = raw_frame['Generosity']
happy_train['Perceptions of corruption'] = raw_frame['Perceptions of corruption']
happy_train['Positive affect'] = raw_frame['Positive affect']
happy_train['Negative affect'] = raw_frame['Negative affect']
happy_train['Report_Age'] = 2020 - happy_train['year']


# Print success message on data imputation
print('Imputing Missing Data Success!!')
# Out:
# Imputing Missing Data Success!!

# %%
# Missing values imputed
happy_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1559 entries, 0 to 1558
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1559 non-null   object
#  1   year                              1559 non-null   int64
#  2   Log GDP per capita                1559 non-null   float64
#  3   Social support                    1559 non-null   float64
#  4   Healthy life expectancy at birth  1559 non-null   float64
#  5   Freedom to make life choices      1559 non-null   float64
#  6   Generosity                        1559 non-null   float64
#  7   Perceptions of corruption         1559 non-null   float64
#  8   Positive affect                   1559 non-null   float64
#  9   Negative affect                   1559 non-null   float64
#  10  ID                                1559 non-null   int64
# ...

# %% [markdown]
# Missing Values are successfully imputed

# %% [markdown]
# **8. Exploratory Data Analysis**

# %% [markdown]
# 1. What is the variation of Life Ladder with the age of the report extracted ?

# %%
# Creating a custom figure size of 10 X 10 inches
figure = plt.figure(figsize=[10, 10])
sns.lineplot(x=happy_train['Report_Age'], y=happy_train['Life Ladder'], ci=None)
plt.xlabel('Report_Age')
plt.ylabel('Life Ladder')
plt.title('Life Ladder over the Report_Age globally')
# Out:
# Text(0.5, 1.0, 'Life Ladder over the Report_Age globally')

# %% [markdown]
# - Life Ladder fell big time in 2006 but started to rise after 2016

# %% [markdown]
# 2. What is the distribution of each feature against Life Ladder

# %%
plt.figure(figsize=(50,50))
sns.pairplot(happy_train)

# %% [markdown]
# - Each feature except ID & Report age seem to be normally distributed ( ID & Report age data will be taken care of later)
# - Except ID & Report Age,  each feature has a linear relationship with Life ladder. So example, Life ladder increases if Positive Effect increases or Log per GDP increases for a person

# %% [markdown]
# 3. What is the correlation of each feature against Life Ladder

# %%
# Correlation plot analysis
corr = happy_train.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,vmax=.8,linewidth=.01, square = True, annot = True,cmap='YlGnBu',linecolor ='black')
plt.title('Correlation between features')
# Out:
# Text(0.5, 1.0, 'Correlation between features')

# %% [markdown]
# - Year, Negative Effect, Pereceptions of corruption features are least correlated to Life Ladder
# - Log GDP, Social Support, Healthy life expectancy at birth, Freedom of choices, Generositym Positive Effect features are highly correlated

# %% [markdown]
# **9. Post Data Processising**

# %%
# Find classes of categorical variables 

# Intialize empty list for categorical features and their length
cat_features = []
label_len = []

# Identify categorical features
for i in happy_train.columns:
  if (happy_train[i].dtype == object):
    cat_features.append(i)

# Identify labels length per leature
for i in cat_features:
  label_len.append(len(happy_train[i].unique()))

# Display total categorical features
print('Total Categorical Features:', len(cat_features))

# Create and show categorical feature frame
cat_frame = pd.DataFrame(data = {'Length': label_len}, index=cat_features)
cat_frame.transpose()
# Out:
# Total Categorical Features: 1
#         Country name
# Length           165

# %%
happy_train.columns
# Out:
# Index(['Country name', 'year', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect', 'ID', 'Life Ladder', 'Report_Age'],
#       dtype='object')

# %%
# Drop ID & Year
happy_train.drop(['year', 'ID'], axis=1, inplace=True)

# %%
happy_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1559 entries, 0 to 1558
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1559 non-null   object
#  1   Log GDP per capita                1559 non-null   float64
#  2   Social support                    1559 non-null   float64
#  3   Healthy life expectancy at birth  1559 non-null   float64
#  4   Freedom to make life choices      1559 non-null   float64
#  5   Generosity                        1559 non-null   float64
#  6   Perceptions of corruption         1559 non-null   float64
#  7   Positive affect                   1559 non-null   float64
#  8   Negative affect                   1559 non-null   float64
#  9   Life Ladder                       1559 non-null   float64
#  10  Report_Age                        1559 non-null   int64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
# Filter data into cat & continuous variable & Target variable
happy_train_con = happy_train[['Log GDP per capita', 'Social support',
       'Healthy life expectancy at birth', 'Freedom to make life choices',
       'Generosity', 'Perceptions of corruption', 'Positive affect',
       'Negative affect','Report_Age']]
print('Data Shape:', happy_train_con.shape)
happy_train_con.head()
# Out:
# Data Shape: (1559, 9)
#    Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0             9.34300         0.76600                          64.22000
# 1            10.29900         0.90100                          67.48000
# 2            10.88100         0.93100                          72.60000
# 3             7.55400         0.72400                          60.64000
# 4            10.94500         0.85640                          65.80000
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                       0.75260    -0.12700                    0.70900
# 1                       0.75400    -0.20100                    0.72600
# 2                       0.94200     0.07700                    0.26300
# 3                       0.70200    -0.08800                    0.76800
# 4                       0.81420     0.13280                    0.41580
#
#    Positive affect  Negative affect  Report_Age
# ...

# %%
# Filter Categorical variable & Target Variable
happy_train_cat = happy_train[['Country name','Life Ladder']]
print('Data Shape:', happy_train_cat.shape)
happy_train_cat.head()
# Out:
# Data Shape: (1559, 2)
#   Country name  Life Ladder
# 0       Jordan      4.93000
# 1      Estonia      5.36700
# 2       Sweden      7.37500
# 3   Tajikistan      4.61300
# 4       Kuwait      6.18000

# %%
# Scaling the continuous variables for train & test data
happy_train_con.columns
# Out:
# Index(['Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect', 'Report_Age'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(happy_train_con)
data1 = scaler.transform(happy_train_con)

# %%
happy_train_con = pd.DataFrame(data1)
happy_train_con.columns = ['Log GDP per capita', 'Social support',
       'Healthy life expectancy at birth', 'Freedom to make life choices',
       'Generosity', 'Perceptions of corruption', 'Positive affect',
       'Negative affect', 'Report_Age']
happy_train_con.head()
# Out:
#    Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0            -0.01619        -0.39707                           0.11606
# 1             0.81234         0.74252                           0.55595
# 2             1.31673         0.99576                           1.24682
# 3            -1.56664        -0.75161                          -0.36700
# 4             1.37220         0.36603                           0.32926
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                       0.07492    -0.78560                   -0.17569
# 1                       0.08482    -1.24380                   -0.08387
# 2                       1.41380     0.47754                   -2.58458
# 3                      -0.28277    -0.54412                    0.14298
# 4                       0.51038     0.82305                   -1.75929
#
#    Positive affect  Negative affect  Report_Age
# 0         -0.36883          0.75665     1.22043
# ...

# %%
# Apply Kfolding on categorical data

class KFoldTargetEncoderTrain(base.BaseEstimator, base.TransformerMixin):

    def __init__(self, colnames,targetName,n_fold=5,verbosity=True,discardOriginal_col=False):

        self.colnames = colnames
        self.targetName = targetName
        self.n_fold = n_fold
        self.verbosity = verbosity
        self.discardOriginal_col = discardOriginal_col

    def fit(self, X, y=None):
        return self


    def transform(self,X):

        assert(type(self.targetName) == str)
        assert(type(self.colnames) == str)
        assert(self.colnames in X.columns)
        assert(self.targetName in X.columns)

        mean_of_target = X[self.targetName].mean()
        kf = KFold(n_splits = self.n_fold, shuffle = False)



        col_mean_name = self.colnames + '_' + 'Kfold_Target_Enc'
        X[col_mean_name] = np.nan

        for tr_ind, val_ind in kf.split(X):
            X_tr, X_val = X.iloc[tr_ind], X.iloc[val_ind]
#             print(tr_ind,val_ind)
            X.loc[X.index[val_ind], col_mean_name] = X_val[self.colnames].map(X_tr.groupby(self.colnames)[self.targetName].mean())

        X[col_mean_name].fillna(mean_of_target, inplace = True)

        if self.verbosity:

            encoded_feature = X[col_mean_name].values
            print('Correlation between the new feature, {} and, {} is {}.'.format(col_mean_name,
                                                                                      self.targetName,
                                                                                      np.corrcoef(X[self.targetName].values, encoded_feature)[0][1]))
        if self.discardOriginal_col:
            X = X.drop(self.targetName, axis=1)
            

        return X

# %%
targetc = KFoldTargetEncoderTrain('Country name','Life Ladder',n_fold=5)
new_happy_train_cat = targetc.fit_transform(happy_train_cat)
# Out:
# Correlation between the new feature, Country name_Kfold_Target_Enc and, Life Ladder is 0.9200637659332537.
# C:\Users\vc00482003\AppData\Local\Temp\ipykernel_1628\1674872047.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col_mean_name] = np.nan
# C:\Users\vc00482003\AppData\Local\Temp\ipykernel_1628\1674872047.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col_mean_name].fillna(mean_of_target, inplace = True)

# %%
new_happy_train_cat.head()
# Drop company name later after encoding
# Out:
#   Country name  Life Ladder  Country name_Kfold_Target_Enc
# 0       Jordan      4.93000                        5.33125
# 1      Estonia      5.36700                        5.71638
# 2       Sweden      7.37500                        7.36800
# 3   Tajikistan      4.61300                        4.95440
# 4       Kuwait      6.18000                        6.21557

# %%
# Concatenate continuous & categorical variables for train Data

final_happy_train = pd.concat([new_happy_train_cat,happy_train_con], axis=1)
print('Data Shape:', final_happy_train.shape)
final_happy_train.head()
# Out:
# Data Shape: (1559, 12)
#   Country name  Life Ladder  Country name_Kfold_Target_Enc  \
# 0       Jordan      4.93000                        5.33125
# 1      Estonia      5.36700                        5.71638
# 2       Sweden      7.37500                        7.36800
# 3   Tajikistan      4.61300                        4.95440
# 4       Kuwait      6.18000                        6.21557
#
#    Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0            -0.01619        -0.39707                           0.11606
# 1             0.81234         0.74252                           0.55595
# 2             1.31673         0.99576                           1.24682
# 3            -1.56664        -0.75161                          -0.36700
# 4             1.37220         0.36603                           0.32926
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                       0.07492    -0.78560                   -0.17569
# ...

# %%
# Dropping ' Country Name'
final_happy_train.drop(['Country name'], axis=1, inplace=True)

# %%
final_happy_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1559 entries, 0 to 1558
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Life Ladder                       1559 non-null   float64
#  1   Country name_Kfold_Target_Enc     1559 non-null   float64
#  2   Log GDP per capita                1559 non-null   float64
#  3   Social support                    1559 non-null   float64
#  4   Healthy life expectancy at birth  1559 non-null   float64
#  5   Freedom to make life choices      1559 non-null   float64
#  6   Generosity                        1559 non-null   float64
#  7   Perceptions of corruption         1559 non-null   float64
#  8   Positive affect                   1559 non-null   float64
#  9   Negative affect                   1559 non-null   float64
#  10  Report_Age                        1559 non-null   float64
# dtypes: float64(11)
# ...

# %% [markdown]
# **10. Data Preparation**

# %%
# Split Train data into depedent & independent variables
x = final_happy_train.drop('Life Ladder', axis = 1)
y = final_happy_train['Life Ladder']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1247, 10)
# (312, 10)
# (1247,)
# (312,)

# %% [markdown]
# **11. Model Development & Evaluation**

# %% [markdown]
# -**Bagging Models**
#
# **a. Random Forest Regressor**

# %%
rf = RandomForestRegressor(n_estimators=50, max_depth = 5)
rf.fit(x_train, y_train)
preds_rf_train = rf.predict(x_train)
preds_rf_test = rf.predict(x_test)

# %%
def model_eval(actual, predicted):
  mse = mean_squared_error(actual, predicted)
  rmse = np.sqrt(mse)
  r2 = r2_score(actual, predicted)
  print('RMSE of Model is: ', round(rmse, 2))
  print('R2 Score of the model is: ', round(r2, 2))

# %%
model_eval(y_train, preds_rf_train)
# Out:
# RMSE of Model is:  0.34
# R2 Score of the model is:  0.91

# %%
model_eval(y_test, preds_rf_test)
# Out:
# RMSE of Model is:  0.42
# R2 Score of the model is:  0.85

# %% [markdown]
# **b. Ada Boosting Regressor**

# %%
ada = AdaBoostRegressor(n_estimators = 600, learning_rate = 0.2)
ada.fit(x_train, y_train)
preds_ada_train = ada.predict(x_train)
preds_ada_test = ada.predict(x_test)

# %%
model_eval(y_train, preds_ada_train)
# Out:
# RMSE of Model is:  0.39
# R2 Score of the model is:  0.88

# %%
model_eval(y_test, preds_ada_test)
# Out:
# RMSE of Model is:  0.46
# R2 Score of the model is:  0.82

# %% [markdown]
# **c. Gradient Boosting Regressor**

# %%
gb = GradientBoostingRegressor(n_estimators=200)
gb.fit(x_train, y_train)
preds_gb_train = gb.predict(x_train)
preds_gb_test = gb.predict(x_test)

# %%
model_eval(y_train, preds_gb_train)
# Out:
# RMSE of Model is:  0.24
# R2 Score of the model is:  0.95

# %%
model_eval(y_test, preds_gb_test)
# Out:
# RMSE of Model is:  0.42
# R2 Score of the model is:  0.86

# %% [markdown]
# **d. Stacking Regressor**

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression

# %%
estimators = [('rf',RandomForestRegressor(n_estimators=50, max_depth = 5)),
              ('knn', KNeighborsRegressor()),
              ('lr', LinearRegression())]

# %%
reg = StackingRegressor(estimators = estimators)

# %%
reg.fit(x_train, y_train)
# Out:
# StackingRegressor(estimators=[('rf',
#                                RandomForestRegressor(max_depth=5,
#                                                      n_estimators=50)),
#                               ('knn', KNeighborsRegressor()),
#                               ('lr', LinearRegression())])

# %%
preds_stack_train = reg.predict(x_train)
preds_stack_test = reg.predict(x_test)

# %%
model_eval(y_train, preds_stack_train)
# Out:
# RMSE of Model is:  0.32
# R2 Score of the model is:  0.92

# %%
model_eval(y_test, preds_stack_test)
# Out:
# RMSE of Model is:  0.4
# R2 Score of the model is:  0.87

# %% [markdown]
# | Model | Bias of Train Data| Variance|Test R2 Score|
# | :-- | :--| :--| :--|
# |**Random Forest**| 0.34 | 6% | 85% |
# |**Ada Boost**| 0.39 | 5% | 82% |
# |**Gradient Boost**| 0.24 | 9% | 86% |
# |**Stacking**| 0.32 | 5% | 87% |
#
#
# **From the above table we observe**:
#
# - Gradient Boost Model has lowest Bias but High Variance hence will cause overfitting
# - Ada Boost has high variance as compared to Random Forest & Stacking Model
# - Random Forest & Stacking model are in par with low variance and bias , but Stacking has lower variance and higer R2 score as compared to Random Forest
# - Hence we wil take Stacking Model on our test data as it has a good accuracy as compared to other models

# %% [markdown]
# **12. Apply Random Forest Model to Test Data**

# %%
# Import Train Data
happy_test = pd.read_csv(r'C:\Users\vc00482003\Desktop\INSAIDclassdocs\ML\ML_Term6_Project\Project_10_Regression_World_Happiness_Report_1\test_data.csv')
print('Data Shape:', happy_test.shape)
happy_test.head()
# Out:
# Data Shape: (390, 11)
#   Country name  year  Log GDP per capita  Social support  \
# 0        Spain  2020            10.48800         0.93500
# 1       Poland  2017            10.31400         0.88200
# 2      Lebanon  2012             9.80000         0.71300
# 3     Malaysia  2011             9.96600         0.77000
# 4       Canada  2020            10.73000         0.93100
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                          75.00000                       0.78300    -0.12100
# 1                          68.90000                       0.83100    -0.12200
# 2                          65.36000                       0.62100    -0.00600
# 3                          65.76000                       0.84000    -0.01600
# 4                          74.00000                       0.88700     0.05000
#
#    Perceptions of corruption  Positive affect  Negative affect    ID
# ...

# %%
#Remove Noisy Data(Dont remove noisy data from Train data as Test Data should be subset of train data, not other way round)
#Training data is used for training the model, in order to get better accuracy large amount of data should be used.
happy_test = happy_test.drop(happy_test.index[happy_test['Country name'].isin(['Oman'])])

# %%
# Export the filtered file
happy_test.to_csv('new_test_data.csv')

# %%
# Import Updated Test Data
happy_test = pd.read_csv(r'C:\Users\vc00482003\Desktop\INSAIDclassdocs\ML\ML_Term6_Project\Project_10_Regression_World_Happiness_Report_1\new_test_data.csv')
print('Data Shape:', happy_test.shape)
happy_test.head()
# Out:
# Data Shape: (389, 11)
#   Country name  year  Log GDP per capita  Social support  \
# 0        Spain  2020            10.48800         0.93500
# 1       Poland  2017            10.31400         0.88200
# 2      Lebanon  2012             9.80000         0.71300
# 3     Malaysia  2011             9.96600         0.77000
# 4       Canada  2020            10.73000         0.93100
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                          75.00000                       0.78300    -0.12100
# 1                          68.90000                       0.83100    -0.12200
# 2                          65.36000                       0.62100    -0.00600
# 3                          65.76000                       0.84000    -0.01600
# 4                          74.00000                       0.88700     0.05000
#
#    Perceptions of corruption  Positive affect  Negative affect    ID
# ...

# %%
# Check Train Data info
happy_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      389 non-null    object
#  1   year                              389 non-null    int64
#  2   Log GDP per capita                379 non-null    float64
#  3   Social support                    387 non-null    float64
#  4   Healthy life expectancy at birth  371 non-null    float64
#  5   Freedom to make life choices      379 non-null    float64
#  6   Generosity                        371 non-null    float64
#  7   Perceptions of corruption         366 non-null    float64
#  8   Positive affect                   385 non-null    float64
#  9   Negative affect                   387 non-null    float64
#  10  ID                                389 non-null    int64
# dtypes: float64(8), int64(2), object(1)
# ...

# %%
# %%time
# Imputing missing data for numerical data
# Have some patience, it may take some time :)
# CPU times: user 7min 27s, sys: 16.6 s, total: 7min 43s
# Wall time: 6min 57s
knn_imputer = KNNImputer()
raw_num = knn_imputer.fit_transform(happy_test[['Log GDP per capita', 'Social support',
       'Healthy life expectancy at birth', 'Freedom to make life choices',
       'Generosity', 'Perceptions of corruption', 'Positive affect',
       'Negative affect']])

# A new dataframe representing non-null values
raw_frame = pd.DataFrame(data=raw_num, columns=['Log GDP per capita', 'Social support',
       'Healthy life expectancy at birth', 'Freedom to make life choices',
       'Generosity', 'Perceptions of corruption', 'Positive affect',
       'Negative affect'])
# Updating original dataset with updated values
happy_test['Log GDP per capita'] = raw_frame['Log GDP per capita']
happy_test['Social support'] = raw_frame['Social support']
happy_test['Healthy life expectancy at birth'] = raw_frame['Healthy life expectancy at birth']
happy_test['Freedom to make life choices'] = raw_frame['Freedom to make life choices']
happy_test['Generosity'] = raw_frame['Generosity']
happy_test['Perceptions of corruption'] = raw_frame['Perceptions of corruption']
happy_test['Positive affect'] = raw_frame['Positive affect']
happy_test['Negative affect'] = raw_frame['Negative affect']
happy_test['Report_Age'] = 2020 - happy_test['year']


# Print success message on data imputation
print('Imputing Missing Data Success!!')
# Out:
# Imputing Missing Data Success!!
# CPU times: total: 15.6 ms
# Wall time: 22.2 ms

# %%
# Missing values imputed
happy_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      389 non-null    object
#  1   year                              389 non-null    int64
#  2   Log GDP per capita                389 non-null    float64
#  3   Social support                    389 non-null    float64
#  4   Healthy life expectancy at birth  389 non-null    float64
#  5   Freedom to make life choices      389 non-null    float64
#  6   Generosity                        389 non-null    float64
#  7   Perceptions of corruption         389 non-null    float64
#  8   Positive affect                   389 non-null    float64
#  9   Negative affect                   389 non-null    float64
#  10  ID                                389 non-null    int64
# ...

# %%
# Find classes of categorical variables 

# Intialize empty list for categorical features and their length
cat_features = []
label_len = []

# Identify categorical features
for i in happy_test.columns:
  if (happy_test[i].dtype == object):
    cat_features.append(i)

# Identify labels length per leature
for i in cat_features:
  label_len.append(len(happy_test[i].unique()))

# Display total categorical features
print('Total Categorical Features:', len(cat_features))

# Create and show categorical feature frame
cat_frame = pd.DataFrame(data = {'Length': label_len}, index=cat_features)
cat_frame.transpose()
# Out:
# Total Categorical Features: 1
#         Country name
# Length           140

# %%
# Drop ID & Year
happy_test.drop(['year', 'ID'], axis=1, inplace=True)

# %%
happy_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      389 non-null    object
#  1   Log GDP per capita                389 non-null    float64
#  2   Social support                    389 non-null    float64
#  3   Healthy life expectancy at birth  389 non-null    float64
#  4   Freedom to make life choices      389 non-null    float64
#  5   Generosity                        389 non-null    float64
#  6   Perceptions of corruption         389 non-null    float64
#  7   Positive affect                   389 non-null    float64
#  8   Negative affect                   389 non-null    float64
#  9   Report_Age                        389 non-null    int64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 30.5+ KB

# %%
# Filter data into cat & continuous variable
happy_test_con = happy_test[['Log GDP per capita', 'Social support',
       'Healthy life expectancy at birth', 'Freedom to make life choices',
       'Generosity', 'Perceptions of corruption', 'Positive affect',
       'Negative affect','Report_Age']]
print('Data Shape:', happy_test_con.shape)
happy_test_con.head()
# Out:
# Data Shape: (389, 9)
#    Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0            10.48800         0.93500                          75.00000
# 1            10.31400         0.88200                          68.90000
# 2             9.80000         0.71300                          65.36000
# 3             9.96600         0.77000                          65.76000
# 4            10.73000         0.93100                          74.00000
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                       0.78300    -0.12100                    0.73000
# 1                       0.83100    -0.12200                    0.63900
# 2                       0.62100    -0.00600                    0.85600
# 3                       0.84000    -0.01600                    0.84200
# 4                       0.88700     0.05000                    0.43400
#
#    Positive affect  Negative affect  Report_Age
# ...

# %%
# Filter Categorical variable
happy_test_cat = happy_test[['Country name']]
print('Data Shape:', happy_test_cat.shape)
happy_test_cat.head()
# Out:
# Data Shape: (389, 1)
#   Country name
# 0        Spain
# 1       Poland
# 2      Lebanon
# 3     Malaysia
# 4       Canada

# %%
# Scaling the continuous variables for train & test data
happy_test_con.columns
# Out:
# Index(['Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect', 'Report_Age'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(happy_test_con)
data1 = scaler.transform(happy_test_con)

# %%
happy_test_con = pd.DataFrame(data1)
happy_test_con.columns = ['Log GDP per capita', 'Social support',
       'Healthy life expectancy at birth', 'Freedom to make life choices',
       'Generosity', 'Perceptions of corruption', 'Positive affect',
       'Negative affect', 'Report_Age']
happy_test_con.head()
# Out:
#    Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0             0.97799         1.05073                           1.51319
# 1             0.82319         0.59794                           0.70673
# 2             0.36590        -0.84586                           0.23872
# 3             0.51359        -0.35890                           0.29160
# 4             1.19328         1.01656                           1.38099
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                       0.27269    -0.78216                   -0.06148
# 1                       0.61665    -0.78856                   -0.55736
# 2                      -0.88817    -0.04648                    0.62511
# 3                       0.68114    -0.11045                    0.54882
# 4                       1.01793     0.31177                   -1.67443
#
#    Positive affect  Negative affect  Report_Age
# 0         -0.28514          0.50690    -1.61329
# ...

# %%
# Apply Kfolding on categorical Test data
class KFoldTargetEncoderTest(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self,train,colNames,encodedName):
        
        self.train = train
        self.colNames = colNames
        self.encodedName = encodedName
        
        
    def fit(self, X, y=None):
        return self

    def transform(self,X):


        mean = self.train[[self.colNames,self.encodedName]].groupby(self.colNames).mean().reset_index() 
        
        dd = {}
        for index, row in mean.iterrows():
            dd[row[self.colNames]] = row[self.encodedName]

        
        X[self.encodedName] = X[self.colNames]
        X = X.replace({self.encodedName: dd})

        return X

# %%
test_targetc = KFoldTargetEncoderTest(new_happy_train_cat,'Country name','Country name_Kfold_Target_Enc')
new_happy_test_cat = test_targetc.fit_transform(happy_test_cat)
# Out:
# C:\Users\vc00482003\AppData\Local\Temp\ipykernel_1628\627778734.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[self.encodedName] = X[self.colNames]

# %%
new_happy_test_cat.head()
# Drop Company name later after encoding
# Out:
#   Country name  Country name_Kfold_Target_Enc
# 0        Spain                        6.32197
# 1       Poland                        5.87224
# 2      Lebanon                        5.00835
# 3     Malaysia                        5.83713
# 4       Canada                        7.44705

# %%
# Concatenate continuous & categorical variables for train Data

final_happy_test = pd.concat([new_happy_test_cat,happy_test_con], axis=1)
print('Data Shape:', final_happy_test.shape)
final_happy_test.head()
# Out:
# Data Shape: (389, 11)
#   Country name  Country name_Kfold_Target_Enc  Log GDP per capita  \
# 0        Spain                        6.32197             0.97799
# 1       Poland                        5.87224             0.82319
# 2      Lebanon                        5.00835             0.36590
# 3     Malaysia                        5.83713             0.51359
# 4       Canada                        7.44705             1.19328
#
#    Social support  Healthy life expectancy at birth  \
# 0         1.05073                           1.51319
# 1         0.59794                           0.70673
# 2        -0.84586                           0.23872
# 3        -0.35890                           0.29160
# 4         1.01656                           1.38099
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                       0.27269    -0.78216                   -0.06148
# 1                       0.61665    -0.78856                   -0.55736
# ...

# %%
# Dropping ' Country Name'
final_happy_test.drop(['Country name'], axis=1, inplace=True)
final_happy_test.head()
# Out:
#    Country name_Kfold_Target_Enc  Log GDP per capita  Social support  \
# 0                        6.32197             0.97799         1.05073
# 1                        5.87224             0.82319         0.59794
# 2                        5.00835             0.36590        -0.84586
# 3                        5.83713             0.51359        -0.35890
# 4                        7.44705             1.19328         1.01656
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                           1.51319                       0.27269    -0.78216
# 1                           0.70673                       0.61665    -0.78856
# 2                           0.23872                      -0.88817    -0.04648
# 3                           0.29160                       0.68114    -0.11045
# 4                           1.38099                       1.01793     0.31177
#
#    Perceptions of corruption  Positive affect  Negative affect  Report_Age
# ...

# %%
final_happy_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name_Kfold_Target_Enc     389 non-null    float64
#  1   Log GDP per capita                389 non-null    float64
#  2   Social support                    389 non-null    float64
#  3   Healthy life expectancy at birth  389 non-null    float64
#  4   Freedom to make life choices      389 non-null    float64
#  5   Generosity                        389 non-null    float64
#  6   Perceptions of corruption         389 non-null    float64
#  7   Positive affect                   389 non-null    float64
#  8   Negative affect                   389 non-null    float64
#  9   Report_Age                        389 non-null    float64
# dtypes: float64(10)
# memory usage: 30.5 KB

# %% [markdown]
# -**Apply Stacking model to Test Data**

# %%
final_happy_test['Life Ladder'] = reg.predict(final_happy_test)

# %%
final_happy_test.head()
# Out:
#    Country name_Kfold_Target_Enc  Log GDP per capita  Social support  \
# 0                        6.32197             0.97799         1.05073
# 1                        5.87224             0.82319         0.59794
# 2                        5.00835             0.36590        -0.84586
# 3                        5.83713             0.51359        -0.35890
# 4                        7.44705             1.19328         1.01656
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                           1.51319                       0.27269    -0.78216
# 1                           0.70673                       0.61665    -0.78856
# 2                           0.23872                      -0.88817    -0.04648
# 3                           0.29160                       0.68114    -0.11045
# 4                           1.38099                       1.01793     0.31177
#
#    Perceptions of corruption  Positive affect  Negative affect  Report_Age  \
# ...

# %%
# Check for any NULL Values
final_happy_test['Life Ladder'].isna().sum()
# Out:
# 0

# %%
# Merge ID & Life Ladder features from Test Data
final_a = final_happy_test['Life Ladder']

# %%
happy_test = pd.read_csv(r'C:\Users\vc00482003\Desktop\INSAIDclassdocs\ML\ML_Term6_Project\Project_10_Regression_World_Happiness_Report_1\new_test_data.csv')
print('Data Shape:', happy_test.shape)
happy_test.head()
# Out:
# Data Shape: (389, 11)
#   Country name  year  Log GDP per capita  Social support  \
# 0        Spain  2020            10.48800         0.93500
# 1       Poland  2017            10.31400         0.88200
# 2      Lebanon  2012             9.80000         0.71300
# 3     Malaysia  2011             9.96600         0.77000
# 4       Canada  2020            10.73000         0.93100
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                          75.00000                       0.78300    -0.12100
# 1                          68.90000                       0.83100    -0.12200
# 2                          65.36000                       0.62100    -0.00600
# 3                          65.76000                       0.84000    -0.01600
# 4                          74.00000                       0.88700     0.05000
#
#    Perceptions of corruption  Positive affect  Negative affect    ID
# ...

# %%
# Filter only ID variable
final_b = happy_test['ID']

# %%
final_submission = pd.concat([final_b,final_a], axis=1, join='inner')

# %%
final_submission.head()
# Out:
#      ID  Life Ladder
# 0  1614      6.36950
# 1  1405      5.91151
# 2   974      4.92007
# 3  1055      6.04193
# 4   307      7.38631

# %%
# Exporting Data for Final Submission
final_submission.to_csv('World_Happined_Project_submission.csv', index=False, header=False)
